# %%
import pandas as pd
import zipfile

# Specify the name of the ZIP archive and the CSV file within it
zip_file_name = "archive.zip"
csv_file_name = "CableTVSubscribersData.csv"

# Open the ZIP archive and read the CSV file
with zipfile.ZipFile(zip_file_name, 'r') as archive:
    with archive.open(csv_file_name) as csv_file:
        # Read the CSV data into a pandas DataFrame
        df = pd.read_csv(csv_file)

# Display the contents of the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12100\966425896.py in <module>
#       8 # Open the ZIP archive and read the CSV file
#       9 with zipfile.ZipFile(zip_file_name, 'r') as archive:
# ---> 10     with archive.open(csv_file_name) as csv_file:
#      11         # Read the CSV data into a pandas DataFrame
#      12         df = pd.read_csv(csv_file)
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in open(self, name, mode, pwd, force_zip64)
#    1509         else:
#    1510             # Get info object for name
# -> 1511             zinfo = self.getinfo(name)
#    1512
#    1513         if mode == 'w':
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in getinfo(self, name)
#    1436         info = self.NameToInfo.get(name)
#    1437         if info is None:
# -> 1438             raise KeyError(
#    1439                 'There is no item named %r in the archive' % name)
#    1440
#
# KeyError: "There is no item named 'CableTVSubscribersData.csv' in the archive"

# %%
import zipfile

zip_file_name = "archive.zip"

# Open the ZIP archive and list its contents
with zipfile.ZipFile(zip_file_name, 'r') as archive:
    file_list = archive.namelist()

print("Contents of the ZIP archive:")
for file_name in file_list:
    print(file_name)
import zipfile

zip_file_name = "archive.zip"

# Open the ZIP archive and list its contents
with zipfile.ZipFile(zip_file_name, 'r') as archive:
    file_list = archive.namelist()

print("Contents of the ZIP archive:")
for file_name in file_list:
    print(file_name)
# Out:
# Contents of the ZIP archive:
# China Video Streaming Apps Overview/AppUsage.csv
# China Video Streaming Apps Overview/NumSubscribers.csv
# China Video Streaming Apps Overview/Revenue.csv
# Disney Plus/Revenue.csv
# Hulu/AdRevenue.csv
# Hulu/LiveTVSubscribers.csv
# Hulu/NumSubscribers.csv
# Hulu/Profit.csv
# Hulu/Revenue.csv
# Hulu/SubscriptionRevenue.csv
# Hulu/Valuation.csv
# LibrarySize.csv
# MinuteSharing.csv
# Netflix/ContentSpend.csv
# Netflix/NumSubscribers.csv
# Netflix/NumSubscribersByRegion.csv
# Netflix/Profit.csv
# Netflix/Revenue.csv
# Netflix/RevenueByRegion.csv
# Tiktok/Revenue.csv
# Tiktok/Users.csv
# Twitch/AdRevenue.csv
# Twitch/ConcurrentViewers.csv
# Twitch/HoursWatched.csv
# Twitch/MostViewedGamesOnTwitch.csv
# Twitch/Revenue.csv
# Twitch/TwitchAgeDemographics.csv
# Twitch/TwitchGenderDemographics.csv
# Twitch/TwitchStreamers.csv
# UK Video Streaming Apps Overview/AppUsage.csv
# UK Video Streaming Apps Overview/NumSubscribers.csv
# UK Video Streaming Apps Overview/Revenue.csv
# USA Video Streaming Apps Overview/AppUsage.csv
# USA Video Streaming Apps Overview/NumSubscribers.csv
# USA Video Streaming Apps Overview/Revenue.csv
# USA Video Streaming Apps Overview/TopPlatforms.csv
# Youtube/PremiumSubscribers.csv
# Youtube/Revenue.csv
# Youtube/Users.csv
# Contents of the ZIP archive:
# China Video Streaming Apps Overview/AppUsage.csv
# China Video Streaming Apps Overview/NumSubscribers.csv
# China Video Streaming Apps Overview/Revenue.csv
# Disney Plus/Revenue.csv
# Hulu/AdRevenue.csv
# Hulu/LiveTVSubscribers.csv
# Hulu/NumSubscribers.csv
# Hulu/Profit.csv
# Hulu/Revenue.csv
# Hulu/SubscriptionRevenue.csv
# Hulu/Valuation.csv
# LibrarySize.csv
# MinuteSharing.csv
# Netflix/ContentSpend.csv
# Netflix/NumSubscribers.csv
# Netflix/NumSubscribersByRegion.csv
# Netflix/Profit.csv
# Netflix/Revenue.csv
# Netflix/RevenueByRegion.csv
# Tiktok/Revenue.csv
# Tiktok/Users.csv
# Twitch/AdRevenue.csv
# Twitch/ConcurrentViewers.csv
# Twitch/HoursWatched.csv
# Twitch/MostViewedGamesOnTwitch.csv
# Twitch/Revenue.csv
# Twitch/TwitchAgeDemographics.csv
# Twitch/TwitchGenderDemographics.csv
# Twitch/TwitchStreamers.csv
# UK Video Streaming Apps Overview/AppUsage.csv
# UK Video Streaming Apps Overview/NumSubscribers.csv
# UK Video Streaming Apps Overview/Revenue.csv
# USA Video Streaming Apps Overview/AppUsage.csv
# USA Video Streaming Apps Overview/NumSubscribers.csv
# USA Video Streaming Apps Overview/Revenue.csv
# USA Video Streaming Apps Overview/TopPlatforms.csv
# Youtube/PremiumSubscribers.csv
# Youtube/Revenue.csv
# Youtube/Users.csv
